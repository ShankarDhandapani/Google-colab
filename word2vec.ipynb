# %% [markdown]
# <a href="https://colab.research.google.com/github/ShankarDhandapani/Google-colab/blob/master/word2vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U gensim
# Out:
# ...
#     100% |████████████████████████████████| 23.5MB 1.0MB/s
# ...
#     100% |████████████████████████████████| 1.4MB 11.7MB/s
# ...
#     100% |████████████████████████████████| 133kB 26.9MB/s
# ...
#     100% |████████████████████████████████| 4.7MB 4.7MB/s
# ...
#     100% |████████████████████████████████| 61kB 20.9MB/s
# ...
#     100% |████████████████████████████████| 552kB 23.6MB/s
# ...
# done
#   Stored in directory: /root/.cache/pip/wheels/73/f1/9b/ccf93d4ba073b6f79b1ed9df68ab5ce048d8136d0efcf90b30
# done
#   Stored in directory: /root/.cache/pip/wheels/81/75/d6/e1317bf09bf1af5a30befc2a007869fa6e1f516b8f7c591cb9
# Successfully built smart-open bz2file
# ...

# %%
# imports needed and set up logging
import gzip
import gensim 
import logging

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-828f6ffc-b8e9-46b4-862e-4951f2729e7e" name="files[]" multiple disabled />
#      <output id="result-828f6ffc-b8e9-46b4-862e-4951f2729e7e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving reviews_data.txt.gz to reviews_data.txt.gz

# %%
data_file="reviews_data.txt.gz"

with gzip.open ('reviews_data.txt.gz', 'rb') as f:
    for i,line in enumerate (f):
        print(line)
        break
# Out:
# b"Oct 12 2009 \tNice trendy hotel location not too bad.\tI stayed in this hotel for one night. As this is a fairly new place some of the taxi drivers did not know where it was and/or did not want to drive there. Once I have eventually arrived at the hotel, I was very pleasantly surprised with the decor of the lobby/ground floor area. It was very stylish and modern. I found the reception's staff geeting me with 'Aloha' a bit out of place, but I guess they are briefed to say that to keep up the coroporate image.As I have a Starwood Preferred Guest member, I was given a small gift upon-check in. It was only a couple of fridge magnets in a gift box, but nevertheless a nice gesture.My room was nice and roomy, there are tea and coffee facilities in each room and you get two complimentary bottles of water plus some toiletries by 'bliss'.The location is not great. It is at the last metro stop and you then need to take a taxi, but if you are not planning on going to see the historic sites in 
# ...

# %%
def read_input(input_file):
    """This method reads the input file which is in gzip format"""
    
    logging.info("reading file {0}...this may take a while".format(input_file))
    
    with gzip.open (input_file, 'rb') as f:
        for i, line in enumerate (f): 

            if (i%10000==0):
                logging.info ("read {0} reviews".format (i))
            # do some pre-processing and return a list of words for each review text
            yield gensim.utils.simple_preprocess (line)

# read the tokenized reviews into a list
# each review item becomes a serries of words
# so this becomes a list of lists
documents = list (read_input (data_file))
logging.info ("Done reading data file")
# Out:
# 2018-09-08 02:04:16,717 : INFO : reading file reviews_data.txt.gz...this may take a while
# 2018-09-08 02:04:16,727 : INFO : read 0 reviews
# 2018-09-08 02:04:19,242 : INFO : read 10000 reviews
# 2018-09-08 02:04:21,887 : INFO : read 20000 reviews
# 2018-09-08 02:04:24,808 : INFO : read 30000 reviews
# 2018-09-08 02:04:27,514 : INFO : read 40000 reviews
# 2018-09-08 02:04:30,509 : INFO : read 50000 reviews
# 2018-09-08 02:04:33,429 : INFO : read 60000 reviews
# 2018-09-08 02:04:35,913 : INFO : read 70000 reviews
# 2018-09-08 02:04:38,150 : INFO : read 80000 reviews
# 2018-09-08 02:04:40,524 : INFO : read 90000 reviews
# 2018-09-08 02:04:42,801 : INFO : read 100000 reviews
# 2018-09-08 02:04:45,571 : INFO : read 110000 reviews
# 2018-09-08 02:04:47,803 : INFO : read 120000 reviews
# 2018-09-08 02:04:50,103 : INFO : read 130000 reviews
# 2018-09-08 02:04:52,580 : INFO : read 140000 reviews
# 2018-09-08 02:04:54,822 : INFO : read 150000 reviews
# ...

# %%
model = gensim.models.Word2Vec (documents, size=150, window=10, min_count=2, workers=10) #window - words, workers - parallel epoch - no of times ds
model.train(documents,total_examples=len(documents),epochs=10)
# Out:
# 2018-09-08 02:05:25,230 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2018-09-08 02:05:25,234 : INFO : collecting all words and their counts
# 2018-09-08 02:05:25,238 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-09-08 02:05:25,567 : INFO : PROGRESS: at sentence #10000, processed 1655714 words, keeping 25777 word types
# 2018-09-08 02:05:25,906 : INFO : PROGRESS: at sentence #20000, processed 3317863 words, keeping 35016 word types
# 2018-09-08 02:05:26,312 : INFO : PROGRESS: at sentence #30000, processed 5264072 words, keeping 47518 word types
# 2018-09-08 02:05:26,678 : INFO : PROGRESS: at sentence #40000, processed 7081746 words, keeping 56675 word types
# 2018-09-08 02:05:27,078 : INFO : PROGRESS: at sentence #50000, processed 9089491 words, keeping 63744 word types
# 2018-09-08 02:05:27,472 : INFO : PROGRESS: at sentence #60000, processed 11013723 words, keeping 76781 word types
# ...

# %%
w1 = "dirty"
model.wv.most_similar (positive=w1)
# Out:
# 2018-09-08 02:27:45,563 : INFO : precomputing L2-norms of word weight vectors
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('filthy', 0.8655557036399841),
#  ('unclean', 0.7968589067459106),
#  ('stained', 0.7791803479194641),
#  ('smelly', 0.7594025135040283),
#  ('grubby', 0.7553955316543579),
#  ('dusty', 0.740359365940094),
#  ('dingy', 0.7364552021026611),
#  ('mouldy', 0.7347421646118164),
#  ('gross', 0.7160559296607971),
#  ('disgusting', 0.7094114422798157)]

# %%
# look up top 6 words similar to 'polite'
w1 = ["polite"]
model.wv.most_similar (positive=w1,topn=6)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('courteous', 0.9249420762062073),
#  ('friendly', 0.8396610617637634),
#  ('cordial', 0.7960987091064453),
#  ('curteous', 0.794013500213623),
#  ('professional', 0.7832014560699463),
#  ('attentive', 0.7829240560531616)]

# %%
# look up top 6 words similar to 'france'
w1 = ["france"]
model.wv.most_similar (positive=w1,topn=6)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('canada', 0.6674602627754211),
#  ('germany', 0.6379154920578003),
#  ('gaulle', 0.6249070167541504),
#  ('austria', 0.6182188391685486),
#  ('england', 0.6110751032829285),
#  ('rome', 0.6067115664482117)]

# %%
# look up top 6 words similar to 'shocked'
w1 = ["shocked"]
model.wv.most_similar (positive=w1,topn=6)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('horrified', 0.7969750165939331),
#  ('amazed', 0.7852365374565125),
#  ('astonished', 0.7837536931037903),
#  ('stunned', 0.7619884014129639),
#  ('appalled', 0.7426004409790039),
#  ('dismayed', 0.7349526882171631)]

# %%
# get everything related to stuff on the bed
w1 = ["bed",'sheet','pillow']
w2 = ['couch']
model.wv.most_similar (positive=w1,negative=w2,topn=10)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('duvet', 0.7104927897453308),
#  ('blanket', 0.7101643085479736),
#  ('mattress', 0.7007207870483398),
#  ('matress', 0.690188467502594),
#  ('quilt', 0.6869824528694153),
#  ('foam', 0.6542372703552246),
#  ('pillows', 0.6407063007354736),
#  ('pillowcase', 0.6354362368583679),
#  ('sheets', 0.6242944598197937),
#  ('comforter', 0.5960012674331665)]

# %%
# similarity between two different words
model.wv.similarity(w1="dirty",w2="smelly")
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 0.7594025

# %%
# similarity between two identical words
model.wv.similarity(w1="dirty",w2="dirty")
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 1.0

# %%
# similarity between two unrelated words
model.wv.similarity(w1="dirty",w2="clean")
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 0.25512767

# %%
# Which one is the odd one out in this list?
model.wv.doesnt_match(["cat","dog","france"])
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 'france'
