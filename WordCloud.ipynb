# %% [markdown]
# <a href="https://colab.research.google.com/github/ShankarDhandapani/Google-colab/blob/master/WordCloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
from wordcloud import WordCloud, STOPWORDS

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-096d7210-b5da-4662-a67a-b3147f45677a" name="files[]" multiple disabled />
#      <output id="result-096d7210-b5da-4662-a67a-b3147f45677a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Book2.csv to Book2.csv

# %%
file = pd.read_csv("Book2.csv")
file
# Out:
#                 Names
# 0             Shankar
# 1                 Ram
# 2              Akaash
# 3   PraveenMuthuKumar
# 4             Pranesh
# 5           Saravanan
# 6         Sunil Kumar
# 7             Nethaji
# 8           Rajadurai
# 9            Prathvik
# 10                Sam
# 11             Sanjay
# 12          Sakthivel
# 13            Prakash
# 14        NaveenKumar
# 15            Shankar
# 16                Ram
# 17             Akaash
# 18  PraveenMuthuKumar
# 19            Pranesh
# 20          Saravanan
# 21        Sunil Kumar
# 22            Nethaji
# 23          Rajadurai
# 24           Prathvik
# 25                Sam
# 26             Sanjay
# 27          Sakthivel
# 28            Prakash
# 29        NaveenKumar

# %%
stopwords = set(STOPWORDS)

# %%
# instantiate a word cloud object
wc = WordCloud(
    background_color='white',
    max_words=2000,
    stopwords=stopwords
)

# generate the word cloud
wc.generate(str(file['Names']))

# %%
# display the word cloud
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.savefig('photo.jpg')
plt.show()
#files.download('photo.jpg')
